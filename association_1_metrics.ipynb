# %% [markdown]
# # **1. 연관분석 이론**

# %% [markdown]
# # 1.4 코랩으로 지표 구해보기
# - 연관분석 주요 지표 구해보기
# - 청년마트 장바구니 데이터를 구성하고, 거래건수, 항목 종수 등 기본정보와 '우유'==> '계란' 에 대한 지지도, 신뢰도, 리프트, 레버리지, 확신 지표를 구한다.

# %% [markdown]
# ## 1.4.1 청년마트 T

# %%
# 1.4.1 청년마트 거래데이터를 리스트(T)로 구성한다.
T = [['우유','계란','커피'],
      ['빵','우유','버터','휴지','라면'],
      ['맥주', '땅콩'],
      ['계란','빵','우유','생수'],
      *** ]

# %% [markdown]
# ## 1.4.2 N,k 및 항목별 횟수

# %%
# 1.4.2 거래 데이터 건수(N), 항목의 개수(k), 개별 항목별 등장 횟수 (i_cnt_dict)를 구한다
# 1.4.2.1 거래건수 N, 

N = ***

# %%
# 1.4.2.2 항목의 개수 출력 k
k =  ***

# %%
# 1.4.2.3 N과 k 출력
print (f'데이터 건수 N = {***}, 항목의 개수 k = {***}')

# %%
# 1.4.2.4 항목별 등장 횟수 출력

# 전체 항목을 단일 목록 구성
full_item_lst = [item for ** in ** for ** in **]

# 집합 set 으로 형변환하여 중복 제거하여 상품목록
unique_item_set = *** (full_item_lst)

#  상품목록 별로 등장 회수 세기
i_cnt_dict = { key_item: full_item_lst.count(key_item) 
                  for *** in unique_item_set }

# 항목별 등장 회수 출력
print ('항목별 등장 횟수')
for item in ***.***() :
  print(item)

# %% [markdown]
# ## 1.4.3 support(우유=>계란)

# %%
# 1.4.3 지지도 support (우유=> 계란)
# 1.4.3.1 거래 데이터 수(N), 우유 등장횟수(f_x), 계란 등장횟수(f_x) 

N= ***
f_x = sum(['우유' in tr for tr in T]) 
f_y = sum([*** for tr in T]) 

print ( f' N = {N}\n Freq(X) = {f_x}  \n Freq(Y) = {f_y} ')
# Out:
#  N = 5
#  Freq(X) = 3
#  Freq(Y) = 3

# %%
# 1.4.3.2 우유와 계란 함께 있는 트랜젝션 개수 (f_x_y)

f_x_y = sum([all(item in tr for item in ['우유','계란'])
             for tr in T
            ])
print(f' Freq(X,Y)= {f_x_y} ')
# Out:
#  Freq(X,Y)= 2

# %%
# 1.4.3.3 support (우유 => 계란)
support= ***
print (f' Support(우유=>계란) = {support:.2f}')
# Out:
#  Support(우유=>계란) = 0.40

# %% [markdown]
# ## 1.4.4 confidence (우유 => 계란)

# %%
# 1.4.4 신뢰도 confidence (우유 => 계란)
confidence = ***
print (f'confidence(우유=>계란) = {confidence:.2f}')
# Out:
# confidence(우유=>계란) = 0.67

# %% [markdown]
# ## 1.4.5 리프트 lift(우유 => 계란)

# %%
# 1.4.5 리프트 lift(우유 => 계란)
lift = ***
print (f'lift(우유 => 계란) = {lift:.2f}')
# Out:
# lift(우유 => 계란) = 1.11

# %% [markdown]
# ## 1.4.6 레버리지 leverage(우유 => 계란)

# %%
# 1.4.6 레버리지 leverage(우유 => 계란)
leverage = ***
print (f'leverage(우유 => 계란) = {leverage:.2f}')
# Out:
# leverage(우유 => 계란) = 0.04

# %% [markdown]
# ## 1.4.7 확신 conviction(우유 => 계란)

# %%
# 1.4.7 확신 conviction(우유 => 계란)
conviction = ***
print (f'conviction(우유 => 계란) = {conviction:.2f}')
# Out:
# conviction(우유 => 계란) = 1.20
